# %%
import os
import cv2
from matplotlib import pyplot as plt

# %%
print(cv2.__version__)
# Out:
# 4.8.1

# %%
os.chdir("D:\\Learning\\udemy_computer_vision_course")

# %%
pwd
# Out:
# 'D:\\Learning\\udemy_computer_vision_course'

# %%
image = cv2.imread("D:\\Learning\\udemy_computer_vision_course\\data\\images\\Sunflowers.jpg")

image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

plt.imshow(image)
plt.title("My Image")
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

# Read the image
image = cv2.imread("D:\\Learning\\udemy_computer_vision_course\\data\\images\\Sunflowers.jpg")

# Display the image
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))  # Convert BGR to RGB for display
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

# Read the image
image = cv2.imread("D:\\Learning\\udemy_computer_vision_course\\data\\images\\Sunflowers.jpg")

image_path = os.path.join("data", "images", "Sunflowers.jpg")

image = cv2.imread(image_path)

# Display the image
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))  # Convert BGR to RGB for display
plt.show()

# %%
image_path = os.path.join("data", "images", "Sunflowers.jpg")

image = cv2.imread(image_path)

image = cv2.cvtColor(image, cv2.COLOR_BAYER_BG2RGB)

plt.imshow(image)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[15], line 5
#       1 image_path = os.path.join("data", "images", "Sunflowers.jpg")
#       3 image = cv2.imread(image_path)
# ----> 5 image = cv2.cvtColor(image, cv2.COLOR_BAYER_BG2RGB)
#       7 plt.imshow(image)
#       8 plt.show()
#
# error: OpenCV(4.8.1) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\demosaicing.cpp:1721: error: (-215:Assertion failed) scn == 1 && (dcn == 3 || dcn == 4) in function 'cv::demosaicing'

# %%
# Out:
# 'data\\images\\Sunflowers.jpg'

# %%
image_path = os.path.join("data", "images", "Sunflowers.jpg")

image = cv2.imread(os.path.join("data", "images", "Sunflowers.jpg"))

plt.imshow(cv2.cvtColor(image, cv2.COLOR_BAYER_BG2RGB))
plt.title("My Image")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[7], line 3
#       1 image = cv2.imread(os.path.join("data", "images", "Sunflowers.jpg"))
# ----> 3 plt.imshow(cv2.cvtColor(image, cv2.COLOR_BAYER_BG2RGB))
#       4 plt.title("My Image")
#       5 plt.show()
#
# error: OpenCV(4.8.1) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\demosaicing.cpp:1721: error: (-215:Assertion failed) scn == 1 && (dcn == 3 || dcn == 4) in function 'cv::demosaicing'

# %%
def imshow(title = "", image = None):
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.title(title)
    plt.show()

# %%
def imshow(title="", image=None):
    if image is None:
        print("Error: Image is None.")
        return

    try:
        # Convert BGR to RGB for display
        rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    except cv2.error as e:
        print(f"Error converting image: {e}")
        return

    plt.imshow(rgb_image)
    plt.title(title)
    plt.show()

# %%
# Example usage:
image_path = "D:\\Learning\\udemy_computer_vision_course\\data\\images\\Sunflowers.jpg"
image = cv2.imread(image_path)
imshow("Sunflowers Image", image)

# %%
image.shape
# Out:
# (359, 580, 3)
