# %%
import os
import cv2
from matplotlib import pyplot as plt
import numpy as np

# %%
os.chdir("D:\\Learning\\udemy_computer_vision_course")

# %%
pwd
# Out:
# 'D:\\Learning\\udemy_computer_vision_course'

# %%
def imshow(title = "", image = None, size = 5):

    # The line below is changed from w, h to h, w
    h, w = image.shape[0], image.shape[1]
    aspect_ratio = w/h

    plt.figure(figsize=(size * aspect_ratio, size))
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.title(title)
    plt.show()

# %%
# Create a black image using numpy to create and array of black 
image = np.zeros((512,512,3), np.uint8)

# Can we make this in black and white? grayscale
image_gray = np.zeros((512,512), np.uint8)

# Black would be the same as a greyscale or color image (same for white)
imshow("Black Canvas - RGB Color", image)
imshow("Black Canvas - Grayscale", image_gray)

# %%
# line

cv2.line(image, (10,20), (100, 200), (255,0,0), 3)
imshow("Line", image)

# %%
# rectangle

cv2.rectangle(image, (100,202), (400, 400), (255,0,0), 3)
imshow("rectangle", image)

# %%
# rectangle

cv2.rectangle(image, (100,202), (400, 400), (255,0,0), 3)
imshow("rectangle", image)

# %%
# circle

cv2.circle(image, (100,202), 200, (0,255,0), -1)
imshow("rectangle", image)
